# %% [markdown]
# <a href="https://colab.research.google.com/github/tripathishiva0123/GPT--2-installation/blob/main/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
from transformers import GPTNeoForCausalLM, GPT2Tokenizer, Trainer, TrainingArguments, pipeline

# Embedded JSON data
data = [
    {
        "prompt": "How does photosynthesis work?",
        "response": "Photosynthesis is the process by which green plants, algae, and some bacteria convert light energy into chemical energy stored in glucose. They use sunlight to transform carbon dioxide and water into glucose and oxygen."
    },
    {
        "prompt": "Explain the theory of relativity.",
        "response": "The theory of relativity, developed by Albert Einstein, includes two parts: special relativity and general relativity. Special relativity addresses the relationship between space and time, while general relativity deals with gravity and the curvature of spacetime."
    }
    # Add more entries as needed
]

# Load the tokenizer and model
model_name = 'EleutherAI/gpt-neo-1.3B'
tokenizer = GPT2Tokenizer.from_pretrained(model_name)
model = GPTNeoForCausalLM.from_pretrained(model_name)

# Preprocess the data
def preprocess_data(data):
    inputs = []
    labels = []
    for entry in data:
        prompt = entry['prompt']
        response = entry['response']
        inputs.append(tokenizer(prompt, return_tensors='pt', truncation=True, padding='max_length'))
        labels.append(tokenizer(response, return_tensors='pt', truncation=True, padding='max_length'))
    return inputs, labels

train_inputs, train_labels = preprocess_data(data)

# Convert data into a dataset for training
class CustomDataset:
    def __init__(self, inputs, labels):
        self.inputs = inputs
        self.labels = labels

    def __len__(self):
        return len(self.inputs)

    def __getitem__(self, idx):
        return {'input_ids': self.inputs[idx]['input_ids'].squeeze(),
                'labels': self.labels[idx]['input_ids'].squeeze()}

train_dataset = CustomDataset(train_inputs, train_labels)

# Training arguments and fine-tuning
training_args = TrainingArguments(
    per_device_train_batch_size=2,
    num_train_epochs=3,
    logging_dir='./logs',
    output_dir='./fine-tuned-model',
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
)

trainer.train()

# Save the fine-tuned model
model.save_pretrained('./fine-tuned-model')
tokenizer.save_pretrained('./fine-tuned-model')

# Load the model for text generation
text_generator = pipeline('text-generation', model='./fine-tuned-model')

# Take user input in a loop
while True:
    user_input = input("Enter your prompt (or type 'exit' to quit): ")
    if user_input.lower() == 'exit':
        break
    output = text_generator(user_input, max_length=100, num_return_sequences=1)
    print(f"Response: {output[0]['generated_text']}")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:99: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/200 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/90.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.35k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/5.31G [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# ...

# %%
import json
from transformers import GPTNeoForCausalLM, GPT2Tokenizer, Trainer, TrainingArguments, pipeline

# Embedded JSON data
data = [
    {
        "prompt": "How does photosynthesis work?",
        "response": "Photosynthesis is the process by which green plants, algae, and some bacteria convert light energy into chemical energy stored in glucose. They use sunlight to transform carbon dioxide and water into glucose and oxygen."
    },
    {
        "prompt": "Explain the theory of relativity.",
        "response": "The theory of relativity, developed by Albert Einstein, includes two parts: special relativity and general relativity. Special relativity addresses the relationship between space and time, while general relativity deals with gravity and the curvature of spacetime."
    }
    # Add more entries as needed
]

# Load the tokenizer and model
model_name = 'EleutherAI/gpt-neo-1.3B'
tokenizer = GPT2Tokenizer.from_pretrained(model_name)

# Set the pad_token to eos_token to avoid the error
tokenizer.pad_token = tokenizer.eos_token

model = GPTNeoForCausalLM.from_pretrained(model_name)

# Preprocess the data
def preprocess_data(data):
    inputs = []
    labels = []
    for entry in data:
        prompt = entry['prompt']
        response = entry['response']
        inputs.append(tokenizer(prompt, return_tensors='pt', truncation=True, padding='max_length'))
        labels.append(tokenizer(response, return_tensors='pt', truncation=True, padding='max_length'))
    return inputs, labels

train_inputs, train_labels = preprocess_data(data)

# Convert data into a dataset for training
class CustomDataset:
    def __init__(self, inputs, labels):
        self.inputs = inputs
        self.labels = labels

    def __len__(self):
        return len(self.inputs)

    def __getitem__(self, idx):
        return {'input_ids': self.inputs[idx]['input_ids'].squeeze(),
                'labels': self.labels[idx]['input_ids'].squeeze()}

train_dataset = CustomDataset(train_inputs, train_labels)

# Training arguments and fine-tuning
training_args = TrainingArguments(
    per_device_train_batch_size=2,
    num_train_epochs=3,
    logging_dir='./logs',
    output_dir='./fine-tuned-model',
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
)

trainer.train()

# Save the fine-tuned model
model.save_pretrained('./fine-tuned-model')
tokenizer.save_pretrained('./fine-tuned-model')

# Load the model for text generation
text_generator = pipeline('text-generation', model='./fine-tuned-model')

# Take user input in a loop
while True:
    user_input = input("Enter your prompt (or type 'exit' to quit): ")
    if user_input.lower() == 'exit':
        break
    output = text_generator(user_input, max_length=100, num_return_sequences=1)
    print(f"Response: {output[0]['generated_text']}")

# %%
training_args = TrainingArguments(
    per_device_train_batch_size=1,  # Reduced from 2 to 1
    num_train_epochs=3,
    logging_dir='./logs',
    output_dir='./fine-tuned-model',
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0c9338faebe7> in <cell line: 1>()
# ----> 1 training_args = TrainingArguments(
#       2     per_device_train_batch_size=1,  # Reduced from 2 to 1
#       3     num_train_epochs=3,
#       4     logging_dir='./logs',
#       5     output_dir='./fine-tuned-model',
#
# NameError: name 'TrainingArguments' is not defined

# %%
import json
from transformers import GPTNeoForCausalLM, GPT2Tokenizer, Trainer, TrainingArguments, pipeline

# Embedded JSON data
data = [
    {
        "prompt": "How does photosynthesis work?",
        "response": "Photosynthesis is the process by which green plants, algae, and some bacteria convert light energy into chemical energy stored in glucose. They use sunlight to transform carbon dioxide and water into glucose and oxygen."
    },
    {
        "prompt": "Explain the theory of relativity.",
        "response": "The theory of relativity, developed by Albert Einstein, includes two parts: special relativity and general relativity. Special relativity addresses the relationship between space and time, while general relativity deals with gravity and the curvature of spacetime."
    }
    # Add more entries as needed
]

# Load the tokenizer and model
model_name = 'EleutherAI/gpt-neo-1.3B'
tokenizer = GPT2Tokenizer.from_pretrained(model_name)

# Set the pad_token to eos_token to avoid the error
tokenizer.pad_token = tokenizer.eos_token

model = GPTNeoForCausalLM.from_pretrained(model_name)

# Preprocess the data
def preprocess_data(data):
    inputs = []
    labels = []
    for entry in data:
        prompt = entry['prompt']
        response = entry['response']
        inputs.append(tokenizer(prompt, return_tensors='pt', truncation=True, padding='max_length', max_length=50))
        labels.append(tokenizer(response, return_tensors='pt', truncation=True, padding='max_length', max_length=50))
    return inputs, labels

train_inputs, train_labels = preprocess_data(data)

# Convert data into a dataset for training
class CustomDataset:
    def __init__(self, inputs, labels):
        self.inputs = inputs
        self.labels = labels

    def __len__(self):
        return len(self.inputs)

    def __getitem__(self, idx):
        return {'input_ids': self.inputs[idx]['input_ids'].squeeze(),
                'labels': self.labels[idx]['input_ids'].squeeze()}

train_dataset = CustomDataset(train_inputs, train_labels)

# Define Training Arguments
training_args = TrainingArguments(
    per_device_train_batch_size=1,  # Reduced batch size
    gradient_accumulation_steps=4,  # Accumulate gradients over 4 steps
    num_train_epochs=3,
    logging_dir='./logs',
    output_dir='./fine-tuned-model',
    fp16=True,  # Enable mixed precision training
)

# Fine-tune the model
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
)

trainer.train()

# Save the fine-tuned model
model.save_pretrained('./fine-tuned-model')
tokenizer.save_pretrained('./fine-tuned-model')

# Load the model for text generation
text_generator = pipeline('text-generation', model='./fine-tuned-model')

# Take user input in a loop
while True:
    user_input = input("Enter your prompt (or type 'exit' to quit): ")
    if user_input.lower() == 'exit':
        break
    output = text_generator(user_input, max_length=100, num_return_sequences=1)
    print(f"Response: {output[0]['generated_text']}")

# %%
import json
from transformers import DistilGPT2Tokenizer, DistilGPT2LMHeadModel, Trainer, TrainingArguments, pipeline

# Embedded JSON data (smaller dataset for testing)
data = [
    {
        "prompt": "What is AI?",
        "response": "AI stands for Artificial Intelligence."
    },
    {
        "prompt": "What is machine learning?",
        "response": "Machine learning is a subset of AI that involves training algorithms to learn patterns from data."
    }
    # Add more entries as needed
]

# Load the tokenizer and model
model_name = 'distilgpt2'
tokenizer = DistilGPT2Tokenizer.from_pretrained(model_name)
model = DistilGPT2LMHeadModel.from_pretrained(model_name)

# Set the pad_token to eos_token to avoid errors
tokenizer.pad_token = tokenizer.eos_token

# Preprocess the data
def preprocess_data(data):
    inputs = []
    labels = []
    for entry in data:
        prompt = entry['prompt']
        response = entry['response']
        inputs.append(tokenizer(prompt, return_tensors='pt', truncation=True, padding='max_length', max_length=50))
        labels.append(tokenizer(response, return_tensors='pt', truncation=True, padding='max_length', max_length=50))
    return inputs, labels

train_inputs, train_labels = preprocess_data(data)

# Convert data into a dataset for training
class CustomDataset:
    def __init__(self, inputs, labels):
        self.inputs = inputs
        self.labels = labels

    def __len__(self):
        return len(self.inputs)

    def __getitem__(self, idx):
        return {'input_ids': self.inputs[idx]['input_ids'].squeeze(),
                'labels': self.labels[idx]['input_ids'].squeeze()}

train_dataset = CustomDataset(train_inputs, train_labels)

# Define Training Arguments
training_args = TrainingArguments(
    per_device_train_batch_size=1,  # Small batch size
    num_train_epochs=1,  # Fewer epochs to reduce training time and resource usage
    logging_dir='./logs',
    output_dir='./fine-tuned-distilgpt2',
)

# Fine-tune the model
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
)

trainer.train()

# Save the fine-tuned model
model.save_pretrained('./fine-tuned-distilgpt2')
tokenizer.save_pretrained('./fine-tuned-distilgpt2')

# Load the model for text generation
text_generator = pipeline('text-generation', model='./fine-tuned-distilgpt2')

# Take user input in a loop
while True:
    user_input = input("Enter your prompt (or type 'exit' to quit): ")
    if user_input.lower() == 'exit':
        break
    output = text_generator(user_input, max_length=50, num_return_sequences=1)
    print(f"Response: {output[0]['generated_text']}")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-e0b6dde807b9> in <cell line: 2>()
#       1 import json
# ----> 2 from transformers import DistilGPT2Tokenizer, DistilGPT2LMHeadModel, Trainer, TrainingArguments, pipeline
#       3
#       4 # Embedded JSON data (smaller dataset for testing)
#       5 data = [
#
# ImportError: cannot import name 'DistilGPT2Tokenizer' from 'transformers' (/usr/local/lib/python3.10/dist-packages/transformers/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import json
from transformers import GPT2Tokenizer, GPT2LMHeadModel, Trainer, TrainingArguments, pipeline

# Embedded JSON data (smaller dataset for testing)
data = [
    {
        "prompt": "What is AI?",
        "response": "AI stands for Artificial Intelligence."
    },
    {
        "prompt": "What is machine learning?",
        "response": "Machine learning is a subset of AI that involves training algorithms to learn patterns from data."
    }
    # Add more entries as needed
]

# Load the tokenizer and model
model_name = 'distilgpt2'
tokenizer = GPT2Tokenizer.from_pretrained(model_name)
model = GPT2LMHeadModel.from_pretrained(model_name)

# Set the pad_token to eos_token to avoid errors
tokenizer.pad_token = tokenizer.eos_token

# Preprocess the data
def preprocess_data(data):
    inputs = []
    labels = []
    for entry in data:
        prompt = entry['prompt']
        response = entry['response']
        inputs.append(tokenizer(prompt, return_tensors='pt', truncation=True, padding='max_length', max_length=50))
        labels.append(tokenizer(response, return_tensors='pt', truncation=True, padding='max_length', max_length=50))
    return inputs, labels

train_inputs, train_labels = preprocess_data(data)

# Convert data into a dataset for training
class CustomDataset:
    def __init__(self, inputs, labels):
        self.inputs = inputs
        self.labels = labels

    def __len__(self):
        return len(self.inputs)

    def __getitem__(self, idx):
        return {'input_ids': self.inputs[idx]['input_ids'].squeeze(),
                'labels': self.labels[idx]['input_ids'].squeeze()}

train_dataset = CustomDataset(train_inputs, train_labels)

# Define Training Arguments
training_args = TrainingArguments(
    per_device_train_batch_size=1,  # Small batch size
    num_train_epochs=1,  # Fewer epochs to reduce training time and resource usage
    logging_dir='./logs',
    output_dir='./fine-tuned-distilgpt2',
)

# Fine-tune the model
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
)

trainer.train()

# Save the fine-tuned model
model.save_pretrained('./fine-tuned-distilgpt2')
tokenizer.save_pretrained('./fine-tuned-distilgpt2')

# Load the model for text generation
text_generator = pipeline('text-generation', model='./fine-tuned-distilgpt2')

# Take user input in a loop
while True:
    user_input = input("Enter your prompt (or type 'exit' to quit): ")
    if user_input.lower() == 'exit':
        break
    output = text_generator(user_input, max_length=50, num_return_sequences=1)
    print(f"Response: {output[0]['generated_text']}")
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/762 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/353M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
#     <div>
#
#       <progress value='2' max='2' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2/2 00:12, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# Enter your prompt (or type 'exit' to quit): What is AI ?
# ...

# %%
import json
from transformers import GPT2Tokenizer, GPT2LMHeadModel, Trainer, TrainingArguments, pipeline

# Expanded JSON data (try to increase diversity)
data = [
    {
        "prompt": "What is AI?",
        "response": "AI stands for Artificial Intelligence. It refers to the simulation of human intelligence in machines."
    },
    {
        "prompt": "What is machine learning?",
        "response": "Machine learning is a subset of AI that involves training algorithms to learn patterns from data."
    },
    {
        "prompt": "Explain photosynthesis.",
        "response": "Photosynthesis is the process by which green plants convert sunlight into chemical energy stored in glucose."
    }
    # Add more entries as needed for better training
]

# Load the tokenizer and model
model_name = 'distilgpt2'
tokenizer = GPT2Tokenizer.from_pretrained(model_name)
model = GPT2LMHeadModel.from_pretrained(model_name)

# Set the pad_token to eos_token to avoid errors
tokenizer.pad_token = tokenizer.eos_token

# Preprocess the data
def preprocess_data(data):
    inputs = []
    labels = []
    for entry in data:
        prompt = entry['prompt']
        response = entry['response']
        inputs.append(tokenizer(prompt, return_tensors='pt', truncation=True, padding='max_length', max_length=50))
        labels.append(tokenizer(response, return_tensors='pt', truncation=True, padding='max_length', max_length=50))
    return inputs, labels

train_inputs, train_labels = preprocess_data(data)

# Convert data into a dataset for training
class CustomDataset:
    def __init__(self, inputs, labels):
        self.inputs = inputs
        self.labels = labels

    def __len__(self):
        return len(self.inputs)

    def __getitem__(self, idx):
        return {'input_ids': self.inputs[idx]['input_ids'].squeeze(),
                'labels': self.labels[idx]['input_ids'].squeeze()}

train_dataset = CustomDataset(train_inputs, train_labels)

# Define Training Arguments
training_args = TrainingArguments(
    per_device_train_batch_size=1,  # Small batch size
    num_train_epochs=3,  # Increase epochs to improve learning
    logging_dir='./logs',
    output_dir='./fine-tuned-distilgpt2',
)

# Fine-tune the model
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
)

trainer.train()

# Save the fine-tuned model
model.save_pretrained('./fine-tuned-distilgpt2')
tokenizer.save_pretrained('./fine-tuned-distilgpt2')

# Load the model for text generation
text_generator = pipeline('text-generation', model='./fine-tuned-distilgpt2', tokenizer=tokenizer)

# Take user input in a loop
while True:
    user_input = input("Enter your prompt (or type 'exit' to quit): ")
    if user_input.lower() == 'exit':
        break
    output = text_generator(user_input, max_length=50, num_return_sequences=1, truncation=True)
    print(f"Response: {output[0]['generated_text']}")
# Out:
#     <div>
#
#       <progress value='9' max='9' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [9/9 00:38, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# Enter your prompt (or type 'exit' to quit): What is AI?
# Response: What is AI? -------------- next part -------------- An HTML attachment was scrubbed...
# Enter your prompt (or type 'exit' to quit): exit

# %%
import json
from transformers import GPT2Tokenizer, GPT2LMHeadModel, Trainer, TrainingArguments, pipeline

# Expanded JSON data with more diverse and complex responses
data = [
    {
        "prompt": "What is AI?",
        "response": "AI, or Artificial Intelligence, refers to the simulation of human intelligence by machines. It involves tasks such as learning, reasoning, problem-solving, and understanding language."
    },
    {
        "prompt": "What is machine learning?",
        "response": "Machine learning is a subset of AI that involves the use of statistical techniques to enable machines to improve at tasks with experience."
    },
    {
        "prompt": "Explain photosynthesis.",
        "response": "Photosynthesis is a process used by plants and other organisms to convert light energy into chemical energy that can later be released to fuel the organism's activities."
    },
    {
        "prompt": "What is the theory of relativity?",
        "response": "The theory of relativity, developed by Albert Einstein, consists of two theories: special relativity and general relativity. It revolutionized the understanding of space, time, and gravity."
    }
    # Add more entries as needed for better training
]

# Load the tokenizer and model
model_name = 'distilgpt2'
tokenizer = GPT2Tokenizer.from_pretrained(model_name)
model = GPT2LMHeadModel.from_pretrained(model_name)

# Set the pad_token to eos_token to avoid errors
tokenizer.pad_token = tokenizer.eos_token

# Preprocess the data
def preprocess_data(data):
    inputs = []
    labels = []
    for entry in data:
        prompt = entry['prompt']
        response = entry['response']
        inputs.append(tokenizer(prompt, return_tensors='pt', truncation=True, padding='max_length', max_length=50))
        labels.append(tokenizer(response, return_tensors='pt', truncation=True, padding='max_length', max_length=50))
    return inputs, labels

train_inputs, train_labels = preprocess_data(data)

# Convert data into a dataset for training
class CustomDataset:
    def __init__(self, inputs, labels):
        self.inputs = inputs
        self.labels = labels

    def __len__(self):
        return len(self.inputs)

    def __getitem__(self, idx):
        return {'input_ids': self.inputs[idx]['input_ids'].squeeze(),
                'labels': self.labels[idx]['input_ids'].squeeze()}

train_dataset = CustomDataset(train_inputs, train_labels)

# Define Training Arguments
training_args = TrainingArguments(
    per_device_train_batch_size=1,  # Small batch size
    num_train_epochs=3,  # Increase epochs to improve learning
    logging_dir='./logs',
    output_dir='./fine-tuned-distilgpt2',
)

# Fine-tune the model
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
)

trainer.train()

# Save the fine-tuned model
model.save_pretrained('./fine-tuned-distilgpt2')
tokenizer.save_pretrained('./fine-tuned-distilgpt2')

# Load the model for text generation
text_generator = pipeline('text-generation', model='./fine-tuned-distilgpt2', tokenizer=tokenizer)

# Take user input in a loop
while True:
    user_input = input("Enter your prompt (or type 'exit' to quit): ")
    if user_input.lower() == 'exit':
        break
    output = text_generator(user_input, max_length=50, num_return_sequences=1, truncation=True)
    print(f"Response: {output[0]['generated_text']}")
# Out:
#     <div>
#
#       <progress value='12' max='12' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [12/12 00:32, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# Enter your prompt (or type 'exit' to quit): What is AI?
# Response: What is AI?
# For the record, there are three categories of AI: A AI, AI, AI. AI is a software program. There is an AI program called A.A.A.A.A. A program that includes a
# Enter your prompt (or type 'exit' to quit): Explain Photosynthesis
# Response: Explain Photosynthesis, and L- and L- the processes that occur in cells.
# Enter your prompt (or type 'exit' to quit): exit

# %%
import json
from transformers import GPT2Tokenizer, GPT2LMHeadModel, Trainer, TrainingArguments, pipeline
import torch
from torch.utils.data import Dataset

# Expanded JSON data with more diverse and complex responses
data = [
    {
        "prompt": "What is AI?",
        "response": "AI, or Artificial Intelligence, refers to the simulation of human intelligence by machines. It involves tasks such as learning, reasoning, problem-solving, and understanding language."
    },
    {
        "prompt": "What is machine learning?",
        "response": "Machine learning is a subset of AI that involves the use of statistical techniques to enable machines to improve at tasks with experience."
    },
    {
        "prompt": "Explain photosynthesis.",
        "response": "Photosynthesis is a process used by plants and other organisms to convert light energy into chemical energy that can later be released to fuel the organism's activities."
    },
    {
        "prompt": "What is the theory of relativity?",
        "response": "The theory of relativity, developed by Albert Einstein, consists of two theories: special relativity and general relativity. It revolutionized the understanding of space, time, and gravity."
    },
    # Add more diverse entries to improve training
]

# Load the tokenizer and model
model_name = 'distilgpt2'
tokenizer = GPT2Tokenizer.from_pretrained(model_name)
model = GPT2LMHeadModel.from_pretrained(model_name)

# Set the pad_token to eos_token to avoid errors
tokenizer.pad_token = tokenizer.eos_token

# Custom Dataset Class
class CustomDataset(Dataset):
    def __init__(self, data, tokenizer, max_length=50):
        self.data = data
        self.tokenizer = tokenizer
        self.max_length = max_length

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        prompt = self.data[idx]['prompt']
        response = self.data[idx]['response']
        input_ids = self.tokenizer.encode(prompt, return_tensors='pt', truncation=True, padding='max_length', max_length=self.max_length).squeeze()
        labels = self.tokenizer.encode(response, return_tensors='pt', truncation=True, padding='max_length', max_length=self.max_length).squeeze()
        return {'input_ids': input_ids, 'labels': labels}

# Preprocess the data and create a dataset
train_dataset = CustomDataset(data, tokenizer)

# Define Training Arguments
training_args = TrainingArguments(
    per_device_train_batch_size=1,  # Small batch size to avoid crashes
    num_train_epochs=5,  # Increase epochs to improve learning
    learning_rate=5e-5,  # Adjust learning rate if needed
    logging_dir='./logs',
    output_dir='./fine-tuned-distilgpt2',
    save_total_limit=2,  # Save only the best models
    evaluation_strategy="steps",
    eval_steps=500,  # Evaluate every 500 steps
)

# Fine-tune the model
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
)

trainer.train()

# Save the fine-tuned model
model.save_pretrained('./fine-tuned-distilgpt2')
tokenizer.save_pretrained('./fine-tuned-distilgpt2')

# Load the model for text generation
text_generator = pipeline('text-generation', model='./fine-tuned-distilgpt2', tokenizer=tokenizer)

# Take user input in a loop
while True:
    user_input = input("Enter your prompt (or type 'exit' to quit): ")
    if user_input.lower() == 'exit':
        break
    output = text_generator(user_input, max_length=50, num_return_sequences=1, truncation=True)
    print(f"Response: {output[0]['generated_text']}")
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1494: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
#     <div>
#
#       <progress value='20' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 00:58, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# Enter your prompt (or type 'exit' to quit): Explain Photosynthesis ?
# Response: Explain Photosynthesis ? ( )
# Enter your prompt (or type 'exit' to quit): Explain theory of relativity ?
# Response: Explain theory of relativity ?
# Enter your prompt (or type 'exit' to quit): exit

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer

# Load the pre-trained model and tokenizer
tokenizer = GPT2Tokenizer.from_pretrained("distilgpt2")
model = GPT2LMHeadModel.from_pretrained("distilgpt2")

def generate_response(prompt):
    # Encode the input prompt
    inputs = tokenizer.encode(prompt, return_tensors="pt")

    # Generate a response from the model
    outputs = model.generate(inputs, max_length=150, num_return_sequences=1)

    # Decode the generated response
    response = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return response

while True:
    # Take user input
    user_input = input("Enter your prompt (or type 'exit' to quit): ")

    # Exit condition
    if user_input.lower() == 'exit':
        break

    # Generate and print the response
    response = generate_response(user_input)
    print("Response:", response)
# Out:
# Enter your prompt (or type 'exit' to quit): What is Photosynthesis
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token.As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Response: What is Photosynthesis?
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Enter your prompt (or type 'exit' to quit): exit

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer
import torch

# Load the pre-trained model and tokenizer
tokenizer = GPT2Tokenizer.from_pretrained("distilgpt2")
model = GPT2LMHeadModel.from_pretrained("distilgpt2")

def generate_response(prompt):
    try:
        # Encode the input prompt
        inputs = tokenizer.encode(prompt, return_tensors="pt")

        # Generate a response from the model
        with torch.no_grad():
            outputs = model.generate(inputs, max_length=100, num_return_sequences=1)

        # Decode the generated response
        response = tokenizer.decode(outputs[0], skip_special_tokens=True)
        return response
    except Exception as e:
        return f"An error occurred: {str(e)}"

while True:
    # Take user input
    user_input = input("Enter your prompt (or type 'exit' to quit): ")

    # Exit condition
    if user_input.lower() == 'exit':
        break

    # Generate and print the response
    response = generate_response(user_input)
    print("Response:", response)
# Out:
# Enter your prompt (or type 'exit' to quit): What is AI ?
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Response: What is AI?
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Enter your prompt (or type 'exit' to quit): exit
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Response: exit __________________
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...

# %%
pip install transformers datasets torch
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.3/527.3 kB 9.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 9.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 9.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 8.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.2
#     Uninstalling pyarrow-14.0.2:
#       Successfully uninstalled pyarrow-14.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 17.0.0 which is incompatible.
# ibis-framework 8.0.0 requires pyarrow<16,>=2, but you have pyarrow 17.0.0 which is incompatible.
# ...

# %%
import torch
from transformers import GPT2LMHeadModel, GPT2Tokenizer, Trainer, TrainingArguments
from torch.utils.data import Dataset

# Define the dataset class
class SimpleDataset(Dataset):
    def __init__(self, tokenizer, data, max_length=512):
        self.input_ids = []
        self.attention_masks = []
        self.labels = []

        for item in data:
            prompt = item['prompt']
            response = item['response']
            # Combine prompt and response for training
            text = prompt + tokenizer.eos_token + response
            encodings = tokenizer(text, truncation=True, padding='max_length', max_length=max_length)
            self.input_ids.append(torch.tensor(encodings['input_ids']))
            self.attention_masks.append(torch.tensor(encodings['attention_mask']))
            self.labels.append(torch.tensor(encodings['input_ids']))

    def __len__(self):
        return len(self.input_ids)

    def __getitem__(self, idx):
        return {
            'input_ids': self.input_ids[idx],
            'attention_mask': self.attention_masks[idx],
            'labels': self.labels[idx],
        }

# Inline JSON data
train_data = [
    {"prompt": "Explain machine learning.", "response": "Machine learning is a method of data analysis that automates analytical model building."},
    {"prompt": "What is reinforcement learning?", "response": "Reinforcement learning is an area of machine learning concerned with how agents should take actions in an environment to maximize cumulative reward."},
    {"prompt": "How does a decision tree work?", "response": "A decision tree is a flowchart-like structure in which each internal node represents a test on an attribute, each branch represents the outcome of the test, and each leaf node represents a class label."},
    {"prompt": "What is overfitting?", "response": "Overfitting occurs when a model learns the details and noise in the training data to the extent that it negatively impacts the model’s performance on new data."},
    {"prompt": "Describe the bias-variance tradeoff.", "response": "The bias-variance tradeoff is the balance between the model’s ability to minimize bias (error due to overly simplistic models) and variance (error due to overly complex models)."}
]

# Initialize tokenizer and model
model_name = 'gpt2'
tokenizer = GPT2Tokenizer.from_pretrained(model_name)
model = GPT2LMHeadModel.from_pretrained(model_name)

# Add pad token if it doesn't exist
tokenizer.pad_token = tokenizer.eos_token

# Create the dataset
dataset = SimpleDataset(tokenizer, train_data)

# Define training arguments
training_args = TrainingArguments(
    output_dir='./results',
    num_train_epochs=3,
    per_device_train_batch_size=2,
    save_steps=10_000,
    save_total_limit=2,
    logging_dir='./logs',
    logging_steps=500,
    evaluation_strategy="steps",
)

# Create Trainer instance
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=dataset,
)

# Fine-tune the model
trainer.train()

# Save the fine-tuned model
model.save_pretrained('./fine-tuned-model')
tokenizer.save_pretrained('./fine-tuned-tokenizer')

# Interactive loop for user input
model.eval()
while True:
    user_input = input("You: ")
    if user_input.lower() == 'exit':
        break

    inputs = tokenizer(user_input, return_tensors='pt', padding=True, truncation=True)
    outputs = model.generate(**inputs, max_length=150, pad_token_id=tokenizer.eos_token_id)

    response = tokenizer.decode(outputs[0], skip_special_tokens=True)
    print(f"AI: {response}")
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1494: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
#     <div>
#
#       <progress value='9' max='9' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [9/9 02:10, Epoch 2.67/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
# ...

# %%
import torch
from transformers import GPT2LMHeadModel, GPT2Tokenizer, Trainer, TrainingArguments
from torch.utils.data import Dataset

# Define the dataset class
class SimpleDataset(Dataset):
    def __init__(self, tokenizer, data, max_length=512):
        self.input_ids = []
        self.attention_masks = []
        self.labels = []

        for item in data:
            prompt = item['prompt']
            response = item['response']
            # Combine prompt and response for training
            text = prompt + tokenizer.eos_token + response
            encodings = tokenizer(text, truncation=True, padding='max_length', max_length=max_length)
            self.input_ids.append(torch.tensor(encodings['input_ids']))
            self.attention_masks.append(torch.tensor(encodings['attention_mask']))
            self.labels.append(torch.tensor(encodings['input_ids']))

    def __len__(self):
        return len(self.input_ids)

    def __getitem__(self, idx):
        return {
            'input_ids': self.input_ids[idx],
            'attention_mask': self.attention_masks[idx],
            'labels': self.labels[idx],
        }

# Inline JSON data
train_data = [
    {"prompt": "Explain machine learning.", "response": "Machine learning is a method of data analysis that automates analytical model building."},
    {"prompt": "What is reinforcement learning?", "response": "Reinforcement learning is an area of machine learning concerned with how agents should take actions in an environment to maximize cumulative reward."},
    {"prompt": "How does a decision tree work?", "response": "A decision tree is a flowchart-like structure in which each internal node represents a test on an attribute, each branch represents the outcome of the test, and each leaf node represents a class label."},
    {"prompt": "What is overfitting?", "response": "Overfitting occurs when a model learns the details and noise in the training data to the extent that it negatively impacts the model’s performance on new data."},
    {"prompt": "Describe the bias-variance tradeoff.", "response": "The bias-variance tradeoff is the balance between the model’s ability to minimize bias (error due to overly simplistic models) and variance (error due to overly complex models)."}
]

# Initialize tokenizer and model
model_name = 'gpt2'
tokenizer = GPT2Tokenizer.from_pretrained(model_name)
model = GPT2LMHeadModel.from_pretrained(model_name)

# Add pad token if it doesn't exist
tokenizer.pad_token = tokenizer.eos_token

# Create the dataset
dataset = SimpleDataset(tokenizer, train_data)

# Define training arguments
training_args = TrainingArguments(
    output_dir='./results',
    num_train_epochs=3,
    per_device_train_batch_size=1,  # Adjust batch size if memory issues occur
    save_steps=1_000,  # Save more frequently
    save_total_limit=2,
    logging_dir='./logs',
    logging_steps=500,
    evaluation_strategy="steps",
)

# Create Trainer instance
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=dataset,
)

# Fine-tune the model with error handling
try:
    trainer.train()
except Exception as e:
    print(f"An error occurred during training: {e}")

# Save the fine-tuned model and tokenizer
try:
    model.save_pretrained('./fine-tuned-model')
    tokenizer.save_pretrained('./fine-tuned-tokenizer')
except Exception as e:
    print(f"An error occurred while saving the model: {e}")

# Interactive loop for user input
model.eval()
while True:
    try:
        user_input = input("You: ")
        if user_input.lower() == 'exit':
            break

        inputs = tokenizer(user_input, return_tensors='pt', padding=True, truncation=True)
        outputs = model.generate(**inputs, max_length=150, pad_token_id=tokenizer.eos_token_id)

        response = tokenizer.decode(outputs[0], skip_special_tokens=True)
        print(f"AI: {response}")

    except Exception as e:
        print(f"An error occurred while generating a response: {e}")
# Out:
#     <div>
#
#       <progress value='7' max='15' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 7/15 01:07 < 01:47, 0.07 it/s, Epoch 1.20/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-b7e90373fb2c> in <cell line: 72>()
#      71 # Fine-tune the model with error handling
#      72 try:
# ---> 73     trainer.train()
#      74 except Exception as e:
#      75     print(f"An error occurred during training: {e}")
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
# ...

# %%
model_name = 'distilgpt2'  # Use a smaller version of GPT-2
tokenizer = GPT2Tokenizer.from_pretrained(model_name)
model = GPT2LMHeadModel.from_pretrained(model_name)

# %%
training_args = TrainingArguments(
    output_dir='./results',
    num_train_epochs=3,
    per_device_train_batch_size=1,  # Reduce batch size
    save_steps=500,  # Save model more frequently
    save_total_limit=3,  # Keep more checkpoints
    logging_dir='./logs',
    logging_steps=100,
    evaluation_strategy="steps",
)

# %%
training_args = TrainingArguments(
    output_dir='./results',
    num_train_epochs=3,
    per_device_train_batch_size=1,  # Reduce batch size
    save_steps=500,  # Save model more frequently
    save_total_limit=3,  # Keep more checkpoints
    logging_dir='./logs',
    logging_steps=100,
    evaluation_strategy="steps",
)

# %%
training_args = TrainingArguments(
    output_dir='./results',
    num_train_epochs=3,
    per_device_train_batch_size=1,  # Reduce batch size
    save_steps=500,  # Save model more frequently
    save_total_limit=3,  # Keep more checkpoints
    logging_dir='./logs',
    logging_steps=100,
    evaluation_strategy="steps",
)

# %%
import logging

# Set up logging
logging.basicConfig(filename='training.log', level=logging.INFO)

try:
    trainer.train()
except Exception as e:
    logging.error(f"An error occurred during training: {e}")
    print(f"An error occurred: {e}")

try:
    model.save_pretrained('./fine-tuned-model')
    tokenizer.save_pretrained('./fine-tuned-tokenizer')
except Exception as e:
    logging.error(f"An error occurred while saving the model: {e}")
    print(f"An error occurred while saving the model: {e}")

while True:
    try:
        user_input = input("You: ")
        if user_input.lower() == 'exit':
            break

        inputs = tokenizer(user_input, return_tensors='pt', padding=True, truncation=True)
        outputs = model.generate(**inputs, max_length=150, pad_token_id=tokenizer.eos_token_id)

        response = tokenizer.decode(outputs[0], skip_special_tokens=True)
        print(f"AI: {response}")

    except Exception as e:
        logging.error(f"An error occurred while generating a response: {e}")
        print(f"An error occurred: {e}")
# Out:
# ERROR:root:An error occurred during training: `AcceleratorState` object has no attribute `distributed_type`. This happens if `AcceleratorState._reset_state()` was called and an `Accelerator` or `PartialState` was not reinitialized.
# An error occurred: `AcceleratorState` object has no attribute `distributed_type`. This happens if `AcceleratorState._reset_state()` was called and an `Accelerator` or `PartialState` was not reinitialized.
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-8-d050e5278364>", line 21, in <cell line: 19>
#     user_input = input("You: ")
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py", line 851, in raw_input
# ...

# %%
import torch
from transformers import GPT2LMHeadModel, GPT2Tokenizer, Trainer, TrainingArguments
from torch.utils.data import Dataset

# Define the dataset class
class SimpleDataset(Dataset):
    def __init__(self, tokenizer, data, max_length=512):
        self.input_ids = []
        self.attention_masks = []
        self.labels = []

        for item in data:
            prompt = item['prompt']
            response = item['response']
            text = prompt + tokenizer.eos_token + response
            encodings = tokenizer(text, truncation=True, padding='max_length', max_length=max_length, return_tensors='pt')
            self.input_ids.append(encodings['input_ids'].s
# Out:
#   File "<ipython-input-9-4804c8c1be97>", line 17
#     self.input_ids.append(encodings['input_ids'].s
#                                                   ^
# SyntaxError: incomplete input

# %%
import torch
from transformers import GPTNeoForCausalLM, GPT2Tokenizer, Trainer, TrainingArguments
from torch.utils.data import Dataset

# Define the dataset class
class CustomDataset(Dataset):
    def __init__(self, tokenizer, data, max_length=512):
        self.input_ids = []
        self.attention_masks = []
        self.labels = []

        for item in data:
            prompt = item['prompt']
            response = item['response']
            text = prompt + tokenizer.eos_token + response
            encodings = tokenizer(text, truncation=True, padding='max_length', max_length=max_length, return_tensors='pt')
            self.input_ids.append(encodings['input_ids'].squeeze())
            self.attention_masks.append(encodings['attention_mask'].squeeze())
            self.labels.append(encodings['input_ids'].squeeze())

    def __len__(self):
        return len(self.input_ids)

    def __getitem__(self, idx):
        return {
            'input_ids': self.input_ids[idx],
            'attention_mask': self.attention_masks[idx],
            'labels': self.labels[idx],
        }

# Example dataset
train_data = [
    {"prompt": "Explain AI.", "response": "Artificial Intelligence is the simulation of human intelligence in machines."},
    {"prompt": "What is supervised learning?", "response": "Supervised learning is a type of machine learning where the model is trained on labeled data."},
    {"prompt": "How does a decision tree work?", "response": "A decision tree is a flowchart-like structure in which each internal node represents a test on an attribute, each branch represents the outcome of the test, and each leaf node represents a class label."},
    {"prompt": "What is reinforcement learning?", "response": "Reinforcement learning is an area of machine learning concerned with how agents should take actions in an environment to maximize cumulative reward."},
    {"prompt": "Describe the bias-variance tradeoff.", "response": "The bias-variance tradeoff is the balance between the model’s ability to minimize bias (error due to overly simplistic models) and variance (error due to overly complex models)."}
]

# Initialize tokenizer and model
model_name = 'EleutherAI/gpt-neo-125M'  # Smaller version of GPT-Neo
tokenizer = GPT2Tokenizer.from_pretrained(model_name)
model = GPTNeoForCausalLM.from_pretrained(model_name)

# Add pad token if it doesn't exist
tokenizer.pad_token = tokenizer.eos_token

# Create the dataset
dataset = CustomDataset(tokenizer, train_data)

# Define training arguments
training_args = TrainingArguments(
    output_dir='./results',
    num_train_epochs=1,  # Start with fewer epochs
    per_device_train_batch_size=2,  # Adjust batch size based on your memory constraints
    save_steps=500,
    save_total_limit=1,
    logging_dir='./logs',
    logging_steps=100,
    evaluation_strategy='steps',  # Use updated parameter
    fp16=False,  # Disable mixed precision if memory issues
    optim='adamw_torch',  # Use AdamW optimizer from PyTorch
)

# Create Trainer instance
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=dataset,
)

# Train and handle potential errors
try:
    trainer.train()
except KeyboardInterrupt:
    print("Training interrupted by user.")
except Exception as e:
    print(f"An error occurred during training: {e}")

# Save the fine-tuned model and tokenizer
try:
    model.save_pretrained('./fine-tuned-model')
    tokenizer.save_pretrained('./fine-tuned-tokenizer')
except Exception as e:
    print(f"An error occurred while saving the model: {e}")

# Interactive loop for user input
model.eval()
while True:
    try:
        user_input = input("You: ")
        if user_input.lower() == 'exit':
            break

        # Prepare input for the model
        input_ids = tokenizer.encode(user_input, return_tensors='pt', padding=True, truncation=True, max_length=512)
        outputs = model.generate(input_ids, max_length=150, pad_token_id=tokenizer.eos_token_id, num_return_sequences=1)

        # Decode and print the response
        response = tokenizer.decode(outputs[0], skip_special_tokens=True)
        print(f"AI: {response}")

    except Exception as e:
        print(f"An error occurred while generating a response: {e}")
# Out:
# tokenizer_config.json:   0%|          | 0.00/727 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/357 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.01k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/526M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/119 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1494: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
#     <div>
#
#       <progress value='3' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3/3 00:59, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
# ...

# %%
import torch
from transformers import GPTNeoForCausalLM, GPT2Tokenizer, Trainer, TrainingArguments
from torch.utils.data import Dataset

# Define the dataset class
class CustomDataset(Dataset):
    def __init__(self, tokenizer, data, max_length=512):
        self.input_ids = []
        self.attention_masks = []
        self.labels = []

        for item in data:
            prompt = item['prompt']
            response = item['response']
            text = prompt + tokenizer.eos_token + response
            encodings = tokenizer(text, truncation=True, padding='max_length', max_length=max_length, return_tensors='pt')
            self.input_ids.append(encodings['input_ids'].squeeze())
            self.attention_masks.append(encodings['attention_mask'].squeeze())
            self.labels.append(encodings['input_ids'].squeeze())

    def __len__(self):
        return len(self.input_ids)

    def __getitem__(self, idx):
        return {
            'input_ids': self.input_ids[idx],
            'attention_mask': self.attention_masks[idx],
            'labels': self.labels[idx],
        }

# Example dataset
train_data = [
    {"prompt": "Explain AI.", "response": "Artificial Intelligence is the simulation of human intelligence in machines."},
    {"prompt": "What is supervised learning?", "response": "Supervised learning is a type of machine learning where the model is trained on labeled data."},
    {"prompt": "How does a decision tree work?", "response": "A decision tree is a flowchart-like structure where each internal node represents a test on an attribute, each branch represents the outcome of the test, and each leaf node represents a class label."},
    {"prompt": "What is reinforcement learning?", "response": "Reinforcement learning is an area of machine learning concerned with how agents should take actions in an environment to maximize cumulative reward."},
    {"prompt": "Describe the bias-variance tradeoff.", "response": "The bias-variance tradeoff is the balance between the model’s ability to minimize bias (error due to overly simplistic models) and variance (error due to overly complex models)."}
]

# Initialize tokenizer and model
model_name = 'EleutherAI/gpt-neo-125M'  # Smaller version of GPT-Neo
tokenizer = GPT2Tokenizer.from_pretrained(model_name)
model = GPTNeoForCausalLM.from_pretrained(model_name)

# Add pad token if it doesn't exist
tokenizer.pad_token = tokenizer.eos_token

# Create the dataset
dataset = CustomDataset(tokenizer, train_data)

# Define training arguments
training_args = TrainingArguments(
    output_dir='./results',
    num_train_epochs=1,  # Start with fewer epochs to prevent overfitting
    per_device_train_batch_size=2,  # Adjust batch size based on memory constraints
    save_steps=500,
    save_total_limit=1,
    logging_dir='./logs',
    logging_steps=100,
    eval_strategy='steps',  # Use updated parameter
    fp16=False,  # Disable mixed precision if memory issues
    optim='adamw_torch',  # Use AdamW optimizer from PyTorch
)

# Create Trainer instance
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=dataset,
)

# Train and handle potential errors
try:
    trainer.train()
except KeyboardInterrupt:
    print("Training interrupted by user.")
except Exception as e:
    print(f"An error occurred during training: {e}")

# Save the fine-tuned model and tokenizer
try:
    model.save_pretrained('./fine-tuned-model')
    tokenizer.save_pretrained('./fine-tuned-tokenizer')
except Exception as e:
    print(f"An error occurred while saving the model: {e}")

# Interactive loop for user input
model.eval()
while True:
    try:
        user_input = input("You: ")
        if user_input.lower() == 'exit':
            break

        # Prepare input for the model
        input_ids = tokenizer.encode(user_input, return_tensors='pt', padding=True, truncation=True, max_length=512)
        attention_mask = (input_ids != tokenizer.pad_token_id).type(torch.int64)

        # Generate a response with adjusted parameters
        outputs = model.generate(
            input_ids,
            attention_mask=attention_mask,
            max_length=150,
            pad_token_id=tokenizer.eos_token_id,
            num_return_sequences=1,
            do_sample=True,  # Enable sampling
            temperature=0.7,  # Adjust temperature for more diverse responses
            top_k=50,  # Consider top 50 most likely tokens
            top_p=0.9,  # Use nucleus sampling to limit to a subset of tokens
            no_repeat_ngram_size=2  # Prevent repetitive n-grams
        )

        # Decode and print the response
        response = tokenizer.decode(outputs[0], skip_special_tokens=True)
        print(f"AI: {response}")

    except Exception as e:
        print(f"An error occurred while generating a response: {e}")
# Out:
#     <div>
#
#       <progress value='3' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3/3 00:59, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# You: What is AI ?
# AI: What is AI?
#
# AI is a method for human beings to create and explore their own lives, and to solve problems. This is the purpose of AI, which is to help you understand and solve a problem.
# This is also the reason why the word “AI” is often used in the English language, as it is used to describe the ability of a human being to do certain things. It is not a term that is applied to all human people, but to those who use it. The word AI is derived from the Greek ‘AI,’ meaning ” to understand the world.“
# ...

# %%
import torch
from transformers import GPTNeoForCausalLM, GPT2Tokenizer, Trainer, TrainingArguments
from torch.utils.data import Dataset

# Define the dataset class
class CustomDataset(Dataset):
    def __init__(self, tokenizer, data, max_length=512):
        self.input_ids = []
        self.attention_masks = []
        self.labels = []

        for item in data:
            prompt = item['prompt']
            response = item['response']
            text = prompt + tokenizer.eos_token + response
            encodings = tokenizer(text, truncation=True, padding='max_length', max_length=max_length, return_tensors='pt')
            self.input_ids.append(encodings['input_ids'].squeeze())
            self.attention_masks.append(encodings['attention_mask'].squeeze())
            self.labels.append(encodings['input_ids'].squeeze())

    def __len__(self):
        return len(self.input_ids)

    def __getitem__(self, idx):
        return {
            'input_ids': self.input_ids[idx],
            'attention_mask': self.attention_masks[idx],
            'labels': self.labels[idx],
        }

# Example dataset
train_data = [
    {"prompt": "Explain AI.", "response": "Artificial Intelligence is the simulation of human intelligence processes by machines, especially computer systems."},
    {"prompt": "What is supervised learning?", "response": "Supervised learning is a type of machine learning where the model is trained on labeled data to make predictions or decisions based on new, unseen data."},
    {"prompt": "How does a decision tree work?", "response": "A decision tree uses a tree-like model of decisions and their possible consequences. It splits data into branches based on feature values and makes predictions based on the majority class in the leaf nodes."},
    {"prompt": "What is reinforcement learning?", "response": "Reinforcement learning involves training an agent to make decisions by rewarding desired behaviors and punishing undesired ones, allowing the agent to learn optimal strategies through trial and error."},
    {"prompt": "Describe the bias-variance tradeoff.", "response": "The bias-variance tradeoff is the balance between a model's ability to minimize bias (error due to overly simplistic models) and variance (error due to overly complex models), aiming for the optimal point where both are minimized."}
]

# Initialize tokenizer and model
model_name = 'EleutherAI/gpt-neo-125M'
tokenizer = GPT2Tokenizer.from_pretrained(model_name)
model = GPTNeoForCausalLM.from_pretrained(model_name)

# Add pad token if it doesn't exist
tokenizer.pad_token = tokenizer.eos_token

# Create the dataset
dataset = CustomDataset(tokenizer, train_data)

# Define training arguments
training_args = TrainingArguments(
    output_dir='./results',
    num_train_epochs=3,  # Increased epochs for better training
    per_device_train_batch_size=2,
    save_steps=500,
    save_total_limit=1,
    logging_dir='./logs',
    logging_steps=100,
    eval_strategy='steps',  # Updated to eval_strategy
    fp16=False,  # Disable mixed precision if memory issues
    optim='adamw_torch',
)

# Create Trainer instance
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=dataset,
)

# Train the model
try:
    trainer.train()
except KeyboardInterrupt:
    print("Training interrupted by user.")
except Exception as e:
    print(f"An error occurred during training: {e}")

# Save the fine-tuned model and tokenizer
try:
    model.save_pretrained('./fine-tuned-model')
    tokenizer.save_pretrained('./fine-tuned-tokenizer')
except Exception as e:
    print(f"An error occurred while saving the model: {e}")

# Interactive loop for user input
model.eval()
while True:
    try:
        user_input = input("You: ")
        if user_input.lower() == 'exit':
            break

        # Prepare input for the model
        inputs = tokenizer(user_input, return_tensors='pt', padding=True, truncation=True, max_length=512)
        input_ids = inputs['input_ids']
        attention_mask = inputs['attention_mask']

        # Generate a response
        outputs = model.generate(
            input_ids,
            attention_mask=attention_mask,
            max_length=150,
            pad_token_id=tokenizer.eos_token_id,
            num_return_sequences=1,
            do_sample=True,  # Enable sampling
            temperature=0.7,  # Adjust temperature for varied responses
            top_k=50,  # Use top-k sampling
            top_p=0.9,  # Use nucleus sampling
            no_repeat_ngram_size=2  # Prevent repetition
        )

        # Decode and print the response
        response = tokenizer.decode(outputs[0], skip_special_tokens=True)
        print(f"AI: {response}")

    except Exception as e:
        print(f"An error occurred while generating a response: {e}")
# Out:
#     <div>
#
#       <progress value='9' max='9' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [9/9 02:42, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# You: Explain AI ?
# AI: Explain AI?
#
# In a previous post, I discussed the AI community, and I think there’s a lot of good AI-related news. However, it‘s important to note that AI is not an invention. It is an ongoing process.
# You: What is supervised learning ?
# AI: What is supervised learning?
#
# In this article, we will look at the two main types of supervised
# learning:
# -   - Unsupervised learning and
#   supervised-learning.
#
# You: What is reinforcement learning ?
# AI: What is reinforcement learning?
#
# ...

# %%
import torch
from transformers import GPTNeoForCausalLM, GPT2Tokenizer, Trainer, TrainingArguments
from torch.utils.data import Dataset

# Define the dataset class
class CustomDataset(Dataset):
    def __init__(self, tokenizer, data, max_length=512):
        self.input_ids = []
        self.attention_masks = []
        self.labels = []

        for item in data:
            prompt = item['prompt']
            response = item['response']
            text = prompt + tokenizer.eos_token + response
            encodings = tokenizer(text, truncation=True, padding='max_length', max_length=max_length, return_tensors='pt')
            self.input_ids.append(encodings['input_ids'].squeeze())
            self.attention_masks.append(encodings['attention_mask'].squeeze())
            self.labels.append(encodings['input_ids'].squeeze())

    def __len__(self):
        return len(self.input_ids)

    def __getitem__(self, idx):
        return {
            'input_ids': self.input_ids[idx],
            'attention_mask': self.attention_masks[idx],
            'labels': self.labels[idx],
        }

# Example dataset
train_data = [
    {"prompt": "Explain AI.", "response": "Artificial Intelligence is the simulation of human intelligence processes by machines, especially computer systems."},
    {"prompt": "What is supervised learning?", "response": "Supervised learning is a type of machine learning where the model is trained on labeled data to make predictions or decisions based on new, unseen data."},
    {"prompt": "How does a decision tree work?", "response": "A decision tree uses a tree-like model of decisions and their possible consequences. It splits data into branches based on feature values and makes predictions based on the majority class in the leaf nodes."},
    {"prompt": "What is reinforcement learning?", "response": "Reinforcement learning involves training an agent to make decisions by rewarding desired behaviors and punishing undesired ones, allowing the agent to learn optimal strategies through trial and error."},
    {"prompt": "Describe the bias-variance tradeoff.", "response": "The bias-variance tradeoff is the balance between a model's ability to minimize bias (error due to overly simplistic models) and variance (error due to overly complex models), aiming for the optimal point where both are minimized."}
]

# Initialize tokenizer and model
model_name = 'EleutherAI/gpt-neo-125M'
tokenizer = GPT2Tokenizer.from_pretrained(model_name)
model = GPTNeoForCausalLM.from_pretrained(model_name)

# Add pad token if it doesn't exist
tokenizer.pad_token = tokenizer.eos_token

# Create the dataset
dataset = CustomDataset(tokenizer, train_data)

# Define training arguments
training_args = TrainingArguments(
    output_dir='./results',
    num_train_epochs=3,  # Increased epochs for better training
    per_device_train_batch_size=2,
    save_steps=500,
    save_total_limit=1,
    logging_dir='./logs',
    logging_steps=100,
    eval_strategy='steps',  # Updated to eval_strategy
    fp16=False,  # Disable mixed precision if memory issues
    optim='adamw_torch',
)

# Create Trainer instance
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=dataset,
)

# Train the model
try:
    trainer.train()
except KeyboardInterrupt:
    print("Training interrupted by user.")
except Exception as e:
    print(f"An error occurred during training: {e}")

# Save the fine-tuned model and tokenizer
try:
    model.save_pretrained('./fine-tuned-model')
    tokenizer.save_pretrained('./fine-tuned-tokenizer')
except Exception as e:
    print(f"An error occurred while saving the model: {e}")

# Interactive loop for user input
model.eval()
while True:
    try:
        user_input = input("You: ")
        if user_input.lower() == 'exit':
            break

        # Prepare input for the model
        inputs = tokenizer(user_input, return_tensors='pt', padding=True, truncation=True, max_length=512)
        input_ids = inputs['input_ids']
        attention_mask = inputs['attention_mask']

        # Generate a response
        outputs = model.generate(
            input_ids,
            attention_mask=attention_mask,
            max_length=150,
            pad_token_id=tokenizer.eos_token_id,
            num_return_sequences=1,
            do_sample=True,  # Enable sampling
            temperature=0.7,  # Adjust temperature for varied responses
            top_k=50,  # Use top-k sampling
            top_p=0.9,  # Use nucleus sampling
            no_repeat_ngram_size=2  # Prevent repetition
        )

        # Decode and print the response
        response = tokenizer.decode(outputs[0], skip_special_tokens=True)
        print(f"AI: {response}")

    except Exception as e:
        print(f"An error occurred while generating a response: {e}")
# Out:
#     <div>
#
#       <progress value='9' max='9' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [9/9 02:26, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# You: Explain AI
# AI: Explain AI from the ground up - a great way to learn AI
#
# What is the "AI" for?
# AI is a tool for learning, learning from, and understanding a world
#
# You: What is supervised learning?
# AI: What is supervised learning?
#
# It's hard to say whether or not learning is a good thing.
#
# You: What is Reinforcement learning ?
# AI: What is Reinforcement learning?
#
# ...

# %%
import torch
from transformers import GPTNeoForCausalLM, GPT2Tokenizer, Trainer, TrainingArguments
from torch.utils.data import Dataset

# Define the dataset class
class CustomDataset(Dataset):
    def __init__(self, tokenizer, data, max_length=512):
        self.input_ids = []
        self.attention_masks = []
        self.labels = []

        for item in data:
            prompt = item['prompt']
            response = item['response']
            text = prompt + tokenizer.eos_token + response
            encodings = tokenizer(text, truncation=True, padding='max_length', max_length=max_length, return_tensors='pt')
            self.input_ids.append(encodings['input_ids'].squeeze())
            self.attention_masks.append(encodings['attention_mask'].squeeze())
            self.labels.append(encodings['input_ids'].squeeze())

    def __len__(self):
        return len(self.input_ids)

    def __getitem__(self, idx):
        return {
            'input_ids': self.input_ids[idx],
            'attention_mask': self.attention_masks[idx],
            'labels': self.labels[idx],
        }

# Example dataset
train_data = [
    {"prompt": "Explain AI.", "response": "Artificial Intelligence is the simulation of human intelligence processes by machines, especially computer systems."},
    {"prompt": "What is supervised learning?", "response": "Supervised learning is a type of machine learning where the model is trained on labeled data to make predictions or decisions based on new, unseen data."},
    {"prompt": "How does a decision tree work?", "response": "A decision tree uses a tree-like model of decisions and their possible consequences. It splits data into branches based on feature values and makes predictions based on the majority class in the leaf nodes."},
    {"prompt": "What is reinforcement learning?", "response": "Reinforcement learning involves training an agent to make decisions by rewarding desired behaviors and punishing undesired ones, allowing the agent to learn optimal strategies through trial and error."},
    {"prompt": "Describe the bias-variance tradeoff.", "response": "The bias-variance tradeoff is the balance between a model's ability to minimize bias (error due to overly simplistic models) and variance (error due to overly complex models), aiming for the optimal point where both are minimized."}
]

# Initialize tokenizer and model
model_name = 'EleutherAI/gpt-neo-125M'
tokenizer = GPT2Tokenizer.from_pretrained(model_name)
model = GPTNeoForCausalLM.from_pretrained(model_name)

# Add pad token if it doesn't exist
tokenizer.pad_token = tokenizer.eos_token

# Create the dataset
dataset = CustomDataset(tokenizer, train_data)

# Define training arguments
training_args = TrainingArguments(
    output_dir='./results',
    num_train_epochs=3,
    per_device_train_batch_size=2,
    save_steps=500,
    save_total_limit=1,
    logging_dir='./logs',
    logging_steps=100,
    eval_strategy='steps',
    fp16=False,
    optim='adamw_torch',
)

# Create Trainer instance
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=dataset,
)

# Train the model
try:
    trainer.train()
except KeyboardInterrupt:
    print("Training interrupted by user.")
except Exception as e:
    print(f"An error occurred during training: {e}")

# Save the fine-tuned model and tokenizer
try:
    model.save_pretrained('./fine-tuned-model')
    tokenizer.save_pretrained('./fine-tuned-tokenizer')
except Exception as e:
    print(f"An error occurred while saving the model: {e}")

# Interactive loop for user input
model.eval()
while True:
    try:
        user_input = input("You: ")
        if user_input.lower() == 'exit':
            break

        # Prepare input for the model
        inputs = tokenizer(user_input, return_tensors='pt', padding=True, truncation=True, max_length=512)
        input_ids = inputs['input_ids']
        attention_mask = inputs['attention_mask']

        # Generate a response
        outputs = model.generate(
            input_ids,
            attention_mask=attention_mask,
            max_length=150,
            pad_token_id=tokenizer.eos_token_id,
            num_return_sequences=1,
            do_sample=True,  # Enable sampling
            temperature=0.7,  # Adjust temperature for varied responses
            top_k=50,  # Use top-k sampling
            top_p=0.9,  # Use nucleus sampling
            no_repeat_ngram_size=2  # Prevent repetition
        )

        # Decode and print the response
        response = tokenizer.decode(outputs[0], skip_special_tokens=True)
        print(f"AI: {response}")

    except Exception as e:
        print(f"An error occurred while generating a response: {e}")
# Out:
#     <div>
#
#       <progress value='9' max='9' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [9/9 02:34, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# You: Explain AI?
# AI: Explain AI?
#
# In a previous post, I discussed the AI community, and I think there’s a lot of good AI-related news. However, it‘s important to note that AI is not an invention. It is a means by which we can make the world a better place.
#
# You: What is supervised learning
# AI: What is supervised learning???????
#
# I am a student in the program. I have been a member of the student group for a year and I am now in my third year of college.
# The problem is that I don't have a computer or an Internet connection to the computer.
# You: exit

# %%
import torch
from transformers import GPTNeoForCausalLM, GPT2Tokenizer, Trainer, TrainingArguments
from torch.utils.data import Dataset

# Define the dataset class
class CustomDataset(Dataset):
    def __init__(self, tokenizer, data, max_length=512):
        self.input_ids = []
        self.attention_masks = []
        self.labels = []

        for item in data:
            prompt = item['prompt']
            response = item['response']
            text = prompt + tokenizer.eos_token + response
            encodings = tokenizer(text, truncation=True, padding='max_length', max_length=max_length, return_tensors='pt')
            self.input_ids.append(encodings['input_ids'].squeeze())
            self.attention_masks.append(encodings['attention_mask'].squeeze())
            self.labels.append(encodings['input_ids'].squeeze())

    def __len__(self):
        return len(self.input_ids)

    def __getitem__(self, idx):
        return {
            'input_ids': self.input_ids[idx],
            'attention_mask': self.attention_masks[idx],
            'labels': self.labels[idx],
        }

# Example dataset
train_data = [
    {"prompt": "Explain AI.", "response": "Artificial Intelligence (AI) is the simulation of human intelligence in machines that are programmed to think and learn like humans. It involves algorithms that can process data, recognize patterns, and make decisions."},
    {"prompt": "What is supervised learning?", "response": "Supervised learning is a type of machine learning where a model is trained on labeled data. The model learns to make predictions or decisions based on the input-output pairs provided during training."},
    {"prompt": "How does a decision tree work?", "response": "A decision tree is a flowchart-like structure where each internal node represents a decision based on a feature, each branch represents the outcome of that decision, and each leaf node represents a class label or decision outcome."},
    {"prompt": "What is reinforcement learning?", "response": "Reinforcement Learning (RL) is a type of machine learning where an agent learns to make decisions by performing actions and receiving rewards or penalties. The goal is to learn a policy that maximizes the cumulative reward."},
    {"prompt": "Describe the bias-variance tradeoff.", "response": "The bias-variance tradeoff is the balance between two types of errors in machine learning: bias, which is error due to overly simplistic models, and variance, which is error due to overly complex models. The aim is to minimize both."}
]

# Initialize tokenizer and model
model_name = 'EleutherAI/gpt-neo-125M'
tokenizer = GPT2Tokenizer.from_pretrained(model_name)
model = GPTNeoForCausalLM.from_pretrained(model_name)

# Add pad token if it doesn't exist
tokenizer.pad_token = tokenizer.eos_token

# Create the dataset
dataset = CustomDataset(tokenizer, train_data)

# Define training arguments
training_args = TrainingArguments(
    output_dir='./results',
    num_train_epochs=3,
    per_device_train_batch_size=2,
    save_steps=500,
    save_total_limit=1,
    logging_dir='./logs',
    logging_steps=100,
    eval_strategy='steps',
    fp16=False,
    optim='adamw_torch',
)

# Create Trainer instance
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=dataset,
)

# Train the model
try:
    trainer.train()
except KeyboardInterrupt:
    print("Training interrupted by user.")
except Exception as e:
    print(f"An error occurred during training: {e}")

# Save the fine-tuned model and tokenizer
try:
    model.save_pretrained('./fine-tuned-model')
    tokenizer.save_pretrained('./fine-tuned-tokenizer')
except Exception as e:
    print(f"An error occurred while saving the model: {e}")

# Interactive loop for user input
model.eval()
while True:
    try:
        user_input = input("You: ")
        if user_input.lower() == 'exit':
            break

        # Prepare input for the model
        inputs = tokenizer(user_input, return_tensors='pt', padding=True, truncation=True, max_length=512)
        input_ids = inputs['input_ids']
        attention_mask = inputs['attention_mask']

        # Generate a response
        outputs = model.generate(
            input_ids,
            attention_mask=attention_mask,
            max_length=150,
            pad_token_id=tokenizer.eos_token_id,
            num_return_sequences=1,
            do_sample=True,  # Enable sampling
            temperature=0.7,  # Adjust temperature for varied responses
            top_k=50,  # Use top-k sampling
            top_p=0.9,  # Use nucleus sampling
            no_repeat_ngram_size=2  # Prevent repetition
        )

        # Decode and print the response
        response = tokenizer.decode(outputs[0], skip_special_tokens=True)
        print(f"AI: {response}")

    except Exception as e:
        print(f"An error occurred while generating a response: {e}")
# Out:
#     <div>
#
#       <progress value='9' max='9' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [9/9 02:59, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# You: explain AI ?
# AI: explain AI?
#
# ~~~
# sabat
# What is the difference between an AI and a computer?
# [https://en.wikipedia.org/wiki/AI_(computer)](https%3A%2F%26en%27%20%C3%81%29%F2%A0%E9%94%99%25%ED%0A5%9F...)
#
# You: exit
# AI: exit
#
# This is the main function of the class.
# @inject Mapping
# public class Mappings {
#
#   @InjectMapping(value = "")
#   public static Map<String, String> map(Map<?, String>) {
# ...
# }
#
# You: exit

# %%
import torch
from transformers import GPTNeoForCausalLM, GPT2Tokenizer, Trainer, TrainingArguments
from torch.utils.data import Dataset

# Define the dataset class
class CustomDataset(Dataset):
    def __init__(self, tokenizer, data, max_length=512):
        self.input_ids = []
        self.attention_masks = []
        self.labels = []

        for item in data:
            prompt = item['prompt']
            response = item['response']
            # Combine prompt and response
            text = prompt + tokenizer.eos_token + response
            encodings = tokenizer(text, truncation=True, padding='max_length', max_length=max_length, return_tensors='pt')
            self.input_ids.append(encodings['input_ids'].squeeze())
            self.attention_masks.append(encodings['attention_mask'].squeeze())
            self.labels.append(encodings['input_ids'].squeeze())

    def __len__(self):
        return len(self.input_ids)

    def __getitem__(self, idx):
        return {
            'input_ids': self.input_ids[idx],
            'attention_mask': self.attention_masks[idx],
            'labels': self.labels[idx],
        }

# Example dataset
train_data = [
    {"prompt": "Explain AI.", "response": "Artificial Intelligence (AI) refers to the simulation of human intelligence in machines that are programmed to think and learn like humans. AI encompasses various techniques and approaches including machine learning, natural language processing, and robotics."},
    {"prompt": "What is supervised learning?", "response": "Supervised learning is a type of machine learning where a model is trained on labeled data. The model learns from the input-output pairs provided during training to make predictions or decisions based on new data."},
    {"prompt": "How does a decision tree work?", "response": "A decision tree is a flowchart-like structure where each internal node represents a decision based on a feature, each branch represents the outcome of that decision, and each leaf node represents a class label or decision outcome. The tree splits data into subsets based on feature values, aiming to achieve the highest information gain or purity."},
    {"prompt": "What is reinforcement learning?", "response": "Reinforcement Learning (RL) is a type of machine learning where an agent learns to make decisions by performing actions and receiving rewards or penalties. The goal is to learn a policy that maximizes cumulative reward through exploration and exploitation of the environment."},
    {"prompt": "Describe the bias-variance tradeoff.", "response": "The bias-variance tradeoff is a concept in machine learning where bias refers to error due to overly simplistic models and variance refers to error due to overly complex models. The goal is to find a balance where both bias and variance are minimized to improve model performance on unseen data."}
]

# Initialize tokenizer and model
model_name = 'EleutherAI/gpt-neo-125M'
tokenizer = GPT2Tokenizer.from_pretrained(model_name)
model = GPTNeoForCausalLM.from_pretrained(model_name)

# Add pad token if it doesn't exist
tokenizer.pad_token = tokenizer.eos_token

# Create the dataset
dataset = CustomDataset(tokenizer, train_data)

# Define training arguments
training_args = TrainingArguments(
    output_dir='./results',
    num_train_epochs=3,
    per_device_train_batch_size=2,
    save_steps=500,
    save_total_limit=1,
    logging_dir='./logs',
    logging_steps=100,
    evaluation_strategy='steps',
    fp16=False,
    optim='adamw_torch',
)

# Create Trainer instance
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=dataset,
)

# Train the model
try:
    trainer.train()
except KeyboardInterrupt:
    print("Training interrupted by user.")
except Exception as e:
    print(f"An error occurred during training: {e}")

# Save the fine-tuned model and tokenizer
try:
    model.save_pretrained('./fine-tuned-model')
    tokenizer.save_pretrained('./fine-tuned-tokenizer')
except Exception as e:
    print(f"An error occurred while saving the model: {e}")

# Interactive loop for user input
model.eval()
while True:
    try:
        user_input = input("You: ")
        if user_input.lower() == 'exit':
            break

        # Prepare input for the model
        inputs = tokenizer(user_input, return_tensors='pt', padding=True, truncation=True, max_length=512)
        input_ids = inputs['input_ids']
        attention_mask = inputs['attention_mask']

        # Generate a response
        outputs = model.generate(
            input_ids,
            attention_mask=attention_mask,
            max_length=150,
            pad_token_id=tokenizer.eos_token_id,
            num_return_sequences=1,
            do_sample=True,  # Enable sampling
            temperature=0.7,  # Adjust temperature for varied responses
            top_k=50,  # Use top-k sampling
            top_p=0.9,  # Use nucleus sampling
            no_repeat_ngram_size=2  # Prevent repetition
        )

        # Decode and print the response
        response = tokenizer.decode(outputs[0], skip_special_tokens=True)
        print(f"AI: {response}")

    except Exception as e:
        print(f"An error occurred while generating a response: {e}")
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1494: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
#     <div>
#
#       <progress value='9' max='9' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [9/9 02:18, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# You: What is AI ?
# AI: What is AI?
#
# AI is a very powerful tool in the field of computer vision. It’s a computer-enhanced technology that can be used to understand and predict the world around us. The first AI-based model was created in 2001 by AI Research.
# You: What is Supervised learning ?
# AI: What is Supervised learning?
#
# ...

# %%
import torch
from transformers import GPTNeoForCausalLM, GPT2Tokenizer, Trainer, TrainingArguments
from torch.utils.data import Dataset

# Define the dataset class
class CustomDataset(Dataset):
    def __init__(self, tokenizer, data, max_length=512):
        self.input_ids = []
        self.attention_masks = []
        self.labels = []

        for item in data:
            prompt = item['prompt']
            response = item['response']
            # Combine prompt and response
            text = prompt + tokenizer.eos_token + response
            encodings = tokenizer(text, truncation=True, padding='max_length', max_length=max_length, return_tensors='pt')
            self.input_ids.append(encodings['input_ids'].squeeze())
            self.attention_masks.append(encodings['attention_mask'].squeeze())
            self.labels.append(encodings['input_ids'].squeeze())

    def __len__(self):
        return len(self.input_ids)

    def __getitem__(self, idx):
        return {
            'input_ids': self.input_ids[idx],
            'attention_mask': self.attention_masks[idx],
            'labels': self.labels[idx],
        }

# Example dataset
train_data = [
    {"prompt": "Explain AI.", "response": "Artificial Intelligence (AI) refers to the simulation of human intelligence in machines that are programmed to think and learn like humans. AI encompasses various techniques and approaches including machine learning, natural language processing, and robotics."},
    {"prompt": "What is supervised learning?", "response": "Supervised learning is a type of machine learning where a model is trained on labeled data. The model learns from the input-output pairs provided during training to make predictions or decisions based on new data."},
    {"prompt": "How does a decision tree work?", "response": "A decision tree is a flowchart-like structure where each internal node represents a decision based on a feature, each branch represents the outcome of that decision, and each leaf node represents a class label or decision outcome. The tree splits data into subsets based on feature values, aiming to achieve the highest information gain or purity."},
    {"prompt": "What is reinforcement learning?", "response": "Reinforcement Learning (RL) is a type of machine learning where an agent learns to make decisions by performing actions and receiving rewards or penalties. The goal is to learn a policy that maximizes cumulative reward through exploration and exploitation of the environment."},
    {"prompt": "Describe the bias-variance tradeoff.", "response": "The bias-variance tradeoff is a concept in machine learning where bias refers to error due to overly simplistic models and variance refers to error due to overly complex models. The goal is to find a balance where both bias and variance are minimized to improve model performance on unseen data."}
]

# Initialize tokenizer and model
model_name = 'EleutherAI/gpt-neo-125M'
tokenizer = GPT2Tokenizer.from_pretrained(model_name)
model = GPTNeoForCausalLM.from_pretrained(model_name)

# Add pad token if it doesn't exist
tokenizer.pad_token = tokenizer.eos_token

# Create the dataset
dataset = CustomDataset(tokenizer, train_data)

# Define training arguments
training_args = TrainingArguments(
    output_dir='./results',
    num_train_epochs=3,
    per_device_train_batch_size=2,
    save_steps=500,
    save_total_limit=1,
    logging_dir='./logs',
    logging_steps=100,
    evaluation_strategy='steps',
    fp16=False,
    optim='adamw_torch',
)

# Create Trainer instance
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=dataset,
)

# Train the model
try:
    trainer.train()
except KeyboardInterrupt:
    print("Training interrupted by user.")
except Exception as e:
    print(f"An error occurred during training: {e}")

# Save the fine-tuned model and tokenizer
try:
    model.save_pretrained('./fine-tuned-model')
    tokenizer.save_pretrained('./fine-tuned-tokenizer')
except Exception as e:
    print(f"An error occurred while saving the model: {e}")

# Interactive loop for user input
model.eval()
while True:
    try:
        user_input = input("You: ")
        if user_input.lower() == 'exit':
            break

        # Prepare input for the model
        inputs = tokenizer(user_input, return_tensors='pt', padding=True, truncation=True, max_length=512)
        input_ids = inputs['input_ids']
        attention_mask = inputs['attention_mask']

        # Generate a response
        outputs = model.generate(
            input_ids,
            attention_mask=attention_mask,
            max_length=150,
            pad_token_id=tokenizer.eos_token_id,
            num_return_sequences=1,
            do_sample=True,  # Enable sampling
            temperature=0.7,  # Adjust temperature for varied responses
            top_k=50,  # Use top-k sampling
            top_p=0.9,  # Use nucleus sampling
            no_repeat_ngram_size=2  # Prevent repetition
        )

        # Decode and print the response
        response = tokenizer.decode(outputs[0], skip_special_tokens=True)
        print(f"AI: {response}")

    except Exception as e:
        print(f"An error occurred while generating a response: {e}")
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1494: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
#     <div>
#
#       <progress value='9' max='9' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [9/9 02:54, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# You: What is a convolutional neural network (CNN)?
# AI: What is a convolutional neural network (CNN)?
#
# CNN is not a network. It is an artificial intelligence (AI) system.
#
# You: What is overfitting in machine learning
# AI: What is overfitting in machine learning
#
# ...

# %%
import torch
from transformers import GPTNeoForCausalLM, GPT2Tokenizer, Trainer, TrainingArguments
from torch.utils.data import Dataset

# Define the dataset class
class CustomDataset(Dataset):
    def __init__(self, tokenizer, data, max_length=512):
        self.input_ids = []
        self.attention_masks = []
        self.labels = []

        for item in data:
            prompt = item['prompt']
            response = item['response']
            # Combine prompt and response
            text = prompt + tokenizer.eos_token + response
            encodings = tokenizer(text, truncation=True, padding='max_length', max_length=max_length, return_tensors='pt')
            self.input_ids.append(encodings['input_ids'].squeeze())
            self.attention_masks.append(encodings['attention_mask'].squeeze())
            self.labels.append(encodings['input_ids'].squeeze())

    def __len__(self):
        return len(self.input_ids)

    def __getitem__(self, idx):
        return {
            'input_ids': self.input_ids[idx],
            'attention_mask': self.attention_masks[idx],
            'labels': self.labels[idx],
        }

# Larger dataset with 12 questions
train_data = [
    {"prompt": "What is AI?", "response": "Artificial Intelligence (AI) is the simulation of human intelligence processes by machines, especially computer systems. These processes include learning, reasoning, and self-correction."},
    {"prompt": "What are the types of AI?", "response": "AI can be classified into three types: Narrow AI (or Weak AI), which is specialized in one task; General AI (or Strong AI), which is capable of performing any cognitive task that a human can; and Artificial Superintelligence, which surpasses human intelligence."},
    {"prompt": "What is supervised learning?", "response": "Supervised learning is a type of machine learning where models are trained on labeled data. The model learns the relationship between input and output and can then make predictions on new, unseen data."},
    {"prompt": "What is unsupervised learning?", "response": "Unsupervised learning involves training models on data without labeled responses. The model tries to find hidden patterns or intrinsic structures in the input data."},
    {"prompt": "What is reinforcement learning?", "response": "Reinforcement Learning (RL) is a type of machine learning where an agent learns to make decisions by taking actions in an environment to maximize cumulative rewards."},
    {"prompt": "What is a neural network?", "response": "A neural network is a series of algorithms that attempt to recognize underlying relationships in a set of data through a process that mimics the way the human brain operates."},
    {"prompt": "What is a decision tree?", "response": "A decision tree is a decision support tool that uses a tree-like graph of decisions and their possible consequences. It's used for both classification and regression tasks."},
    {"prompt": "What is a support vector machine (SVM)?", "response": "A Support Vector Machine (SVM) is a supervised learning model used for classification and regression tasks. It works by finding the hyperplane that best separates the data into different classes."},
    {"prompt": "What is a convolutional neural network (CNN)?", "response": "A Convolutional Neural Network (CNN) is a type of deep learning model that is particularly effective for image recognition and classification tasks. It uses convolutional layers to automatically and adaptively learn spatial hierarchies of features."},
    {"prompt": "What is natural language processing (NLP)?", "response": "Natural Language Processing (NLP) is a branch of AI that focuses on the interaction between computers and humans through natural language. It involves tasks like language translation, sentiment analysis, and speech recognition."},
    {"prompt": "What is overfitting in machine learning?", "response": "Overfitting occurs when a model learns the details and noise in the training data to the extent that it negatively impacts the performance on new data. It typically happens when the model is too complex."},
    {"prompt": "What is cross-validation?", "response": "Cross-validation is a technique for assessing how the results of a statistical analysis will generalize to an independent data set. It is commonly used to evaluate the performance of a machine learning model and to prevent overfitting."}
]

# Initialize tokenizer and model
model_name = 'EleutherAI/gpt-neo-125M'
tokenizer = GPT2Tokenizer.from_pretrained(model_name)
model = GPTNeoForCausalLM.from_pretrained(model_name)

# Add pad token if it doesn't exist
tokenizer.pad_token = tokenizer.eos_token

# Create the dataset
dataset = CustomDataset(tokenizer, train_data)

# Define training arguments
training_args = TrainingArguments(
    output_dir='./results',
    num_train_epochs=3,
    per_device_train_batch_size=2,
    save_steps=500,
    save_total_limit=1,
    logging_dir='./logs',
    logging_steps=100,
    evaluation_strategy='steps',
    fp16=False,
    optim='adamw_torch',
)

# Create Trainer instance
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=dataset,
)

# Train the model
try:
    trainer.train()
except KeyboardInterrupt:
    print("Training interrupted by user.")
except Exception as e:
    print(f"An error occurred during training: {e}")

# Save the fine-tuned model and tokenizer
try:
    model.save_pretrained('./fine-tuned-model')
    tokenizer.save_pretrained('./fine-tuned-tokenizer')
except Exception as e:
    print(f"An error occurred while saving the model: {e}")

# Interactive loop for user input
model.eval()
while True:
    try:
        user_input = input("You: ")
        if user_input.lower() == 'exit':
            break

        # Prepare input for the model
        inputs = tokenizer(user_input, return_tensors='pt', padding=True, truncation=True, max_length=512)
        input_ids = inputs['input_ids']
        attention_mask = inputs['attention_mask']

        # Generate a response
        outputs = model.generate(
            input_ids,
            attention_mask=attention_mask,
            max_length=150,
            pad_token_id=tokenizer.eos_token_id,
            num_return_sequences=1,
            do_sample=True,  # Enable sampling
            temperature=0.7,  # Adjust temperature for varied responses
            top_k=50,  # Use top-k sampling
            top_p=0.9,  # Use nucleus sampling
            no_repeat_ngram_size=2  # Prevent repetition
        )

        # Decode and print the response
        response = tokenizer.decode(outputs[0], skip_special_tokens=True)
        print(f"AI: {response}")

    except Exception as e:
        print(f"An error occurred while generating a response: {e}")
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1494: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
#     <div>
#
#       <progress value='18' max='18' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [18/18 06:19, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# You:  What is AI ?
# AI:  What is AI?
# You: exit
